# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime as dt
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.support import expected_conditions as EC
import os
import wget

option = webdriver.ChromeOptions()
option.add_argument('--headless')
option.add_argument('--no-sandbox')
option.add_argument('--disable-dev-shm-usage')
option.add_argument("--disable-gpu") 
option.add_argument("--window-size=1280,720")


driver = webdriver.Chrome('chromedriver', options = option)
driver.get('https://www.instagram.com/')
# driver.find_element_by_xpath('//*[@id="table_1_length"]/label/div/select/option[7]').click()

# %%
# driver.find_element_by_xpath()

# %%
username = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//input[@placeholder='username']"))) 
# password = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='password']"))) 

username.clear()
# password.clear()
username.send_keys("avia_tionspace")
# password.send_keys("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25c89b8fcf22> in <module>()
# ----> 1 username = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//input[@placeholder='username']")))
#       2 # password = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='password']")))
#       3
#       4 username.clear()
#       5 # password.clear()
#
# NameError: name 'WebDriverWait' is not defined

# %%
x = 'https://instagram.fcgk4-6.fna.fbcdn.net/v/t51.2885-15/sh0.08/e35/s640x640/203852407_1386466778401318_5193295601123488654_n.jpg?_nc_ht=instagram.fcgk4-6.fna.fbcdn.net&_nc_cat=110&_nc_ohc=vNpuDQJssFwAX_kpyeB&edm=APU89FABAAAA&ccb=7-4&oh=a64e4017bf1b907c0cd77fc6ccfb529b&oe=613EF9E7&_nc_sid=86f79a'

# %%
from PIL import Image
import requests

pil_image = Image.open(requests.get(x, stream=True).raw)
pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7F0ABFC65B38>

# %%
# Crop the iceberg portion
gambar_data = pil_image.crop((742,410,960,800))
gambar_data2 = pil_image.crop((90,910,962,1000))
gambar_data
# Out:
# <PIL.Image.Image image mode=RGB size=218x390 at 0x7F0ABFC1EA58>

# %%
# !python -V
# Out:
# Python 3.6.10 :: Anaconda, Inc.
